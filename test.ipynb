# %%
import numpy as np, matplotlib.pyplot as plt
from scipy.io.wavfile import read

# %%
sr1, x1 = read('sounds/piano.wav')
sr2, x2 = read('sounds/output.wav')

plt.plot(x1/np.max(np.abs(x1)))
plt.plot(x2/np.max(np.abs(x2)))
